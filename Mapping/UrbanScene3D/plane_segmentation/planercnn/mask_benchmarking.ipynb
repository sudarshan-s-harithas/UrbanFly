# %%
from plane_segmentor import PlaneSegmentor

# %%
from options import parse_args

# %%
import pickle as pkl
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt

# %%
with open('options.pkl', 'rb') as f:
    options = pkl.load(f)

# %%
options
# Out:
# Namespace(LR=1e-05, MaskRCNNPath='../mask_rcnn_coco.pth', anchorFolder='anchors/', anchorType='normal', batchSize=16, blocks='', considerPartial=False, convType='2', cornerLocationNoise=0.0, cornerPositiveWeight=0, correctionType='one', customDataFolder='example_images', dataFolder='../../Data/ScanNet/', dataset='inference', debug=False, distanceThreshold2D=20, distanceThreshold3D=0.2, frameGap=20, gpu=1, heatmapThreshold=0.5, height=512, keyname='inference', locationNoise=0.0, losses='', maskHeight=56, maskWeight=1, maskWidth=56, methods='f', minNumPointRatio=0.05, modelType='', numAnchorPlanes=0, numEpochs=1000, numInputChannels=4, numNodes=10, numPositiveExamples=200, numTestingImages=100, numTrainingImages=1000, numViews=0, occlusionNoise=0, outputDim=256, planeAreaThreshold=500, planeWidthThreshold=10, positiveWeight=0.33, predictAdjacency=False, restore=1, savePoints=False, scaleMode='variant', startEpoch=-1, suffix='warping_refine', task='train', test_dir='test/inference', tes
# ...

# %%
from config import InferenceConfig

# %%
config = InferenceConfig(options)
camera = np.array([320, 320, 320, 240, 640, 480])

# %%
data_dir = '/home/rrc/UrbanScene3D/recordings/L_shape_20Hz_img/captures'

# %%
img = cv2.imread(os.path.join(data_dir,'0_scene.png'))
seg_img = cv2.imread(os.path.join(data_dir,'0_seg.png'))

# %%
img = img[:,:,::-1]

# %%
plt.imshow(img)

# %%
cv2.imwrite('test.png', img)
# Out:
# True

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
from plane_segmentor import PlaneSegmentor

# %%
segmentor = PlaneSegmentor(options,config, camera)

# %%
img = cv2.resize(img, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_26154/2144813865.py in <module>
# ----> 1 img = cv2.resize(img, )
#
# TypeError: resize() missing required argument 'dsize' (pos 2)

# %%
plt.imshow(mask)

# %% [markdown]
# cv2.resize(img,dsize=(240,320), interpolation=cv2.INTER_NEAREST)

# %%
img_small = cv2.resize(img,dsize=(320,240), interpolation=cv2.INTER_NEAREST)

# %%
seg_small = cv2.resize(seg_img,dsize=(320,240), interpolation=cv2.INTER_NEAREST)

# %%
img_small.shape
# Out:
# (240, 320, 3)

# %%
mask = segmentor.segment(img_small, seg_small)
# Out:
# 320
# 320
# 240 320
# hi
# 1.3333333333333333
# 1.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_26367/1997582093.py in <module>
# ----> 1 mask = segmentor.segment(img_small, seg_small)
#
# ~/skyline/plane_segmentation/plane_segmentation/planercnn/plane_segmentor.py in segment(self, rgb_image, seg_image)
#      36         Returns: plane segmented image
#      37         """
# ---> 38         masks, parameters = self.detect_planes(rgb_image)
#      39         masks = self.filter_planes(rgb_image, seg_image, masks)
#      40         plane_mask = self.merge_masks(masks)
#
# ~/skyline/plane_segmentation/plane_segmentation/planercnn/plane_segmentor.py in detect_planes(self, rgb_image)
#      49         Return: masks, parameters
#      50         """
# ---> 51         return self.detector.run(rgb_image)
#      52
# ...

# %%
config.IMAGE_MAX_DIM=320
config.IMAGE_MIN_DIM=240

# %%
# %load_ext autoreload

# %%
# %autoreload 2
